# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 715

# %%
# Import the requests library
import requests

#Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 106.9816, 'lat': 13.4878},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 73.99,
#   'feels_like': 74.46,
#   'temp_min': 73.99,
#   'temp_max': 73.99,
#   'pressure': 1014,
#   'humidity': 72,
#   'sea_level': 1014,
#   'grnd_level': 1002},
#  'visibility': 10000,
#  'wind': {'speed': 8.08, 'deg': 92},
#  'clouds': {'all': 0},
#  'dt': 1615149643,
#  'sys': {'country': 'KH', 'sunrise': 1615158261, 'sunset': 1615201304},
#  'timezone': 25200,
#  'id': 1830377,
#  'name': 'Lumphat',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 1 | belaya gora
# Processing Record 4 of Set 1 | notodden
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | noyon
# Processing Record 11 of Set 1 | beyneu
# Processing Record 12 of Set 1 | bulungu
# Processing Record 13 of Set 1 | sulangan
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | cabedelo
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | livingstonia
# Processing Record 29 of Set 1 | cayenne
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | soure
# Processing Record 33 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 1 | beringovskiy
# Processing Record 35 of Set 1 | praia
# Processing Record 36 of Set 1 | husavik
# Processing Record 37 of Set 1 | sibu
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | kirakira
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | silvania
# Processing Record 47 of Set 1 | toma
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | benjamin hill
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | faya
# Processing Record 4 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 2 | foz
# Processing Record 6 of Set 2 | mitsamiouli
# Processing Record 7 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 8 of Set 2 | do rud
# City not found. Skipping...
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | rio claro
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | la ronge
# Processing Record 14 of Set 2 | puro
# Processing Record 15 of Set 2 | lamar
# Processing Record 16 of Set 2 | mount isa
# Processing Record 17 of Set 2 | vallenar
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | melfi
# Processing Record 20 of Set 2 | port shepstone
# Processing Record 21 of Set 2 | dumai
# Processing Record 22 of Set 2 | bushehr
# Processing Record 23 of Set 2 | huntly
# Processing Record 24 of Set 2 | horsham
# Processing Record 25 of Set 2 | riyadh
# Processing Record 26 of Set 2 | vanimo
# Processing Record 27 of Set 2 | mangai
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | obidos
# Processing Record 30 of Set 2 | egvekinot
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | beloha
# Processing Record 34 of Set 2 | dicabisagan
# Processing Record 35 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 2 | ulaanbaatar
# Processing Record 37 of Set 2 | katangli
# Processing Record 38 of Set 2 | balangir
# Processing Record 39 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 2 | kokkola
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | agva
# City not found. Skipping...
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | antalaha
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | esperance
# Processing Record 48 of Set 2 | shubarshi
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | pokrovsk
# Processing Record 3 of Set 3 | sobolevo
# Processing Record 4 of Set 3 | loreto
# Processing Record 5 of Set 3 | zaltan
# Processing Record 6 of Set 3 | ushuaia
# Processing Record 7 of Set 3 | grand gaube
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | bubaque
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | elbistan
# Processing Record 16 of Set 3 | iwanai
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | pelym
# Processing Record 19 of Set 3 | svetlyy
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | washington
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | skagen
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | ngunguru
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | oranjestad
# Processing Record 28 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | matadi
# Processing Record 31 of Set 3 | filadelfia
# Processing Record 32 of Set 3 | durant
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | soyo
# Processing Record 36 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 3 | kabinda
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | mersing
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | dharchula
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | nioro
# Processing Record 45 of Set 3 | alice springs
# Processing Record 46 of Set 3 | andenes
# Processing Record 47 of Set 3 | kapaa
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | shache
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | alta floresta
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | pili
# Processing Record 6 of Set 4 | port macquarie
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | salinopolis
# Processing Record 9 of Set 4 | nhulunbuy
# Processing Record 10 of Set 4 | lavrentiya
# Processing Record 11 of Set 4 | killybegs
# Processing Record 12 of Set 4 | aykhal
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | flin flon
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 4 | hobart
# Processing Record 18 of Set 4 | odessa
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | springdale
# Processing Record 21 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 4 | arkhangelskoye
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | zainsk
# Processing Record 26 of Set 4 | honiara
# Processing Record 27 of Set 4 | monrovia
# Processing Record 28 of Set 4 | suntar
# Processing Record 29 of Set 4 | beira
# Processing Record 30 of Set 4 | awbari
# Processing Record 31 of Set 4 | ginda
# Processing Record 32 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 4 | okha
# Processing Record 34 of Set 4 | nazare
# Processing Record 35 of Set 4 | vidalia
# Processing Record 36 of Set 4 | puerto plata
# Processing Record 37 of Set 4 | sept-iles
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 4 | dakar
# Processing Record 44 of Set 4 | narrabri
# Processing Record 45 of Set 4 | hwange
# Processing Record 46 of Set 4 | juigalpa
# Processing Record 47 of Set 4 | kavaratti
# Processing Record 48 of Set 4 | sorong
# Processing Record 49 of Set 4 | kanniyakumari
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | marsh harbour
# Processing Record 3 of Set 5 | ust-tsilma
# Processing Record 4 of Set 5 | hammerfest
# Processing Record 5 of Set 5 | amapa
# Processing Record 6 of Set 5 | suez
# Processing Record 7 of Set 5 | dutse
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | dongning
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | vila franca do campo
# Processing Record 12 of Set 5 | sao miguel do araguaia
# Processing Record 13 of Set 5 | kyren
# Processing Record 14 of Set 5 | saint-philippe
# Processing Record 15 of Set 5 | nouadhibou
# Processing Record 16 of Set 5 | neuquen
# Processing Record 17 of Set 5 | eyl
# Processing Record 18 of Set 5 | mabaruma
# Processing Record 19 of Set 5 | alofi
# Processing Record 20 of Set 5 | verkhnevilyuysk
# Processing Record 21 of Set 5 | fortuna
# Processing Record 22 of Set 5 | noicattaro
# Processing Record 23 of Set 5 | flinders
# Processing Record 24 of Set 5 | coquimbo
# Processing Record 25 of Set 5 | vagur
# Processing Record 26 of Set 5 | natal
# Processing Record 27 of Set 5 | beroroha
# Processing Record 28 of Set 5 | vao
# Processing Record 29 of Set 5 | the pas
# Processing Record 30 of Set 5 | pokhara
# Processing Record 31 of Set 5 | san cristobal
# Processing Record 32 of Set 5 | saint george
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | verkhoyansk
# Processing Record 36 of Set 5 | parrita
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | yuli
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | auki
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | kidal
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | carnarvon
# Processing Record 46 of Set 5 | namatanai
# Processing Record 47 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | whitehorse
# Processing Record 50 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 6 | pecos
# Processing Record 2 of Set 6 | buraydah
# Processing Record 3 of Set 6 | guadalupe y calvo
# Processing Record 4 of Set 6 | jacareacanga
# Processing Record 5 of Set 6 | kondopoga
# Processing Record 6 of Set 6 | quelimane
# Processing Record 7 of Set 6 | buchanan
# Processing Record 8 of Set 6 | hay river
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | srednekolymsk
# Processing Record 11 of Set 6 | kauhajoki
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | gornyak
# Processing Record 15 of Set 6 | brattvag
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | xuddur
# Processing Record 18 of Set 6 | llangefni
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | lastoursville
# Processing Record 21 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | paamiut
# Processing Record 25 of Set 6 | havelock
# Processing Record 26 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 6 | terrace bay
# Processing Record 28 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | dukat
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | san ramon
# Processing Record 33 of Set 6 | dawei
# Processing Record 34 of Set 6 | utete
# Processing Record 35 of Set 6 | tual
# Processing Record 36 of Set 6 | kathmandu
# Processing Record 37 of Set 6 | ilhabela
# Processing Record 38 of Set 6 | chuy
# Processing Record 39 of Set 6 | qurayyat
# Processing Record 40 of Set 6 | kalmunai
# Processing Record 41 of Set 6 | kavieng
# Processing Record 42 of Set 6 | khandyga
# Processing Record 43 of Set 6 | novaya malykla
# Processing Record 44 of Set 6 | huarmey
# Processing Record 45 of Set 6 | severo-yeniseyskiy
# Processing Record 46 of Set 6 | clifton
# Processing Record 47 of Set 6 | castro
# Processing Record 48 of Set 6 | djibo
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 50 of Set 6 | gunjur
# Processing Record 1 of Set 7 | sassandra
# Processing Record 2 of Set 7 | necochea
# Processing Record 3 of Set 7 | kaitangata
# Processing Record 4 of Set 7 | vaitape
# Processing Record 5 of Set 7 | sioux lookout
# Processing Record 6 of Set 7 | hokitika
# Processing Record 7 of Set 7 | clyde river
# Processing Record 8 of Set 7 | college
# Processing Record 9 of Set 7 | smithers
# Processing Record 10 of Set 7 | katima mulilo
# Processing Record 11 of Set 7 | banda aceh
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | praia da vitoria
# Processing Record 14 of Set 7 | roebourne
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | monterey
# Processing Record 17 of Set 7 | geraldton
# Processing Record 18 of Set 7 | khoy
# Processing Record 19 of Set 7 | pacific grove
# Processing Record 20 of Set 7 | harrisburg
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | takoradi
# Processing Record 24 of Set 7 | hamilton
# Processing Record 25 of Set 7 | vardo
# Processing Record 26 of Set 7 | narsaq
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | yermakovskoye
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | przasnysz
# Processing Record 32 of Set 7 | mayor pablo lagerenza
# Processing Record 33 of Set 7 | stokmarknes
# Processing Record 34 of Set 7 | bud
# Processing Record 35 of Set 7 | jauja
# Processing Record 36 of Set 7 | skegness
# Processing Record 37 of Set 7 | krasnoselkup
# Processing Record 38 of Set 7 | shar
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | souillac
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | bayir
# Processing Record 43 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 44 of Set 7 | makakilo city
# Processing Record 45 of Set 7 | pila
# Processing Record 46 of Set 7 | takaungu
# Processing Record 47 of Set 7 | rabat
# Processing Record 48 of Set 7 | los llanos de aridane
# Processing Record 49 of Set 7 | port blair
# Processing Record 50 of Set 7 | mae sai
# Processing Record 1 of Set 8 | tembisa
# Processing Record 2 of Set 8 | bhattiprolu
# Processing Record 3 of Set 8 | eureka
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | upleta
# Processing Record 6 of Set 8 | port-cartier
# Processing Record 7 of Set 8 | tomatlan
# Processing Record 8 of Set 8 | minbu
# Processing Record 9 of Set 8 | inhambane
# Processing Record 10 of Set 8 | tiksi
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | tursunzoda
# Processing Record 13 of Set 8 | iranshahr
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | biscarrosse
# Processing Record 16 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 8 | chachapoyas
# Processing Record 18 of Set 8 | pangkalanbuun
# Processing Record 19 of Set 8 | zaranj
# Processing Record 20 of Set 8 | maarianhamina
# Processing Record 21 of Set 8 | thunder bay
# Processing Record 22 of Set 8 | ebano
# City not found. Skipping...
# Processing Record 23 of Set 8 | butembo
# Processing Record 24 of Set 8 | gornopravdinsk
# Processing Record 25 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 8 | yian
# City not found. Skipping...
# Processing Record 27 of Set 8 | ponta delgada
# Processing Record 28 of Set 8 | anloga
# Processing Record 29 of Set 8 | koutsouras
# Processing Record 30 of Set 8 | ahipara
# Processing Record 31 of Set 8 | rio gallegos
# Processing Record 32 of Set 8 | macusani
# Processing Record 33 of Set 8 | waddan
# Processing Record 34 of Set 8 | margate
# Processing Record 35 of Set 8 | dire dawa
# Processing Record 36 of Set 8 | ulety
# Processing Record 37 of Set 8 | durango
# Processing Record 38 of Set 8 | kyabe
# Processing Record 39 of Set 8 | teguldet
# Processing Record 40 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | pleasanton
# Processing Record 42 of Set 8 | muisne
# Processing Record 43 of Set 8 | parabel
# Processing Record 44 of Set 8 | kotido
# Processing Record 45 of Set 8 | dong hoi
# Processing Record 46 of Set 8 | remontnoye
# Processing Record 47 of Set 8 | toora-khem
# Processing Record 48 of Set 8 | umm lajj
# Processing Record 49 of Set 8 | dologon
# Processing Record 50 of Set 8 | boatlaname
# City not found. Skipping...
# Processing Record 1 of Set 9 | dudinka
# Processing Record 2 of Set 9 | curuca
# Processing Record 3 of Set 9 | caraballeda
# Processing Record 4 of Set 9 | coripata
# Processing Record 5 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 6 of Set 9 | svetlogorsk
# Processing Record 7 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 9 | tunceli
# Processing Record 9 of Set 9 | frederikshavn
# Processing Record 10 of Set 9 | yining
# Processing Record 11 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 12 of Set 9 | tiarei
# Processing Record 13 of Set 9 | shimoda
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | taksimo
# Processing Record 16 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 9 | luanda
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | leshukonskoye
# Processing Record 20 of Set 9 | crato
# Processing Record 21 of Set 9 | northam
# Processing Record 22 of Set 9 | saryozek
# Processing Record 23 of Set 9 | wakiso
# Processing Record 24 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 9 | goure
# Processing Record 26 of Set 9 | baoqing
# Processing Record 27 of Set 9 | puerto escondido
# Processing Record 28 of Set 9 | strezhevoy
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | port hawkesbury
# Processing Record 31 of Set 9 | zyryanka
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | general roca
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | novoselitskoye
# Processing Record 36 of Set 9 | raga
# Processing Record 37 of Set 9 | bowen
# Processing Record 38 of Set 9 | ossora
# Processing Record 39 of Set 9 | qaqortoq
# Processing Record 40 of Set 9 | laguna
# Processing Record 41 of Set 9 | half moon bay
# Processing Record 42 of Set 9 | tenenkou
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | tongchuan
# Processing Record 45 of Set 9 | machico
# Processing Record 46 of Set 9 | lufilufi
# Processing Record 47 of Set 9 | bull savanna
# Processing Record 48 of Set 9 | isparta
# Processing Record 49 of Set 9 | gravdal
# Processing Record 50 of Set 9 | dickinson
# Processing Record 1 of Set 10 | angoram
# Processing Record 2 of Set 10 | itarema
# Processing Record 3 of Set 10 | sompeta
# Processing Record 4 of Set 10 | requena
# Processing Record 5 of Set 10 | kota kinabalu
# Processing Record 6 of Set 10 | sao felix do xingu
# Processing Record 7 of Set 10 | stubbekobing
# Processing Record 8 of Set 10 | pangnirtung
# Processing Record 9 of Set 10 | muros
# Processing Record 10 of Set 10 | istanbul
# Processing Record 11 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 12 of Set 10 | borgosesia
# Processing Record 13 of Set 10 | comodoro rivadavia
# Processing Record 14 of Set 10 | puerto baquerizo moreno
# Processing Record 15 of Set 10 | kayerkan
# Processing Record 16 of Set 10 | tilichiki
# Processing Record 17 of Set 10 | mogadishu
# Processing Record 18 of Set 10 | goderich
# Processing Record 19 of Set 10 | ust-karsk
# Processing Record 20 of Set 10 | kloulklubed
# Processing Record 21 of Set 10 | bilma
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | apac
# Processing Record 24 of Set 10 | novhorodka
# Processing Record 25 of Set 10 | caravelas
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | dahra
# Processing Record 28 of Set 10 | erdenet
# Processing Record 29 of Set 10 | carballo
# Processing Record 30 of Set 10 | santa helena
# Processing Record 31 of Set 10 | odweyne
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | kautokeino
# Processing Record 34 of Set 10 | san lawrenz
# Processing Record 35 of Set 10 | ouadda
# Processing Record 36 of Set 10 | marzuq
# Processing Record 37 of Set 10 | maksatikha
# Processing Record 38 of Set 10 | great yarmouth
# Processing Record 39 of Set 10 | vestmannaeyjar
# Processing Record 40 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 10 | sukhoverkovo
# City not found. Skipping...
# Processing Record 42 of Set 10 | winnemucca
# Processing Record 43 of Set 10 | balaipungut
# Processing Record 44 of Set 10 | hirara
# Processing Record 45 of Set 10 | yumen
# Processing Record 46 of Set 10 | linxia
# Processing Record 47 of Set 10 | praya
# Processing Record 48 of Set 10 | vilyuysk
# Processing Record 49 of Set 10 | rio grande
# Processing Record 50 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 11 | ler
# Processing Record 2 of Set 11 | escanaba
# Processing Record 3 of Set 11 | kokopo
# Processing Record 4 of Set 11 | kusti
# Processing Record 5 of Set 11 | kupang
# Processing Record 6 of Set 11 | marsa matruh
# Processing Record 7 of Set 11 | pimentel
# Processing Record 8 of Set 11 | san quintin
# Processing Record 9 of Set 11 | jizan
# Processing Record 10 of Set 11 | bismarck
# Processing Record 11 of Set 11 | redencao
# Processing Record 12 of Set 11 | opelousas
# Processing Record 13 of Set 11 | isangel
# Processing Record 14 of Set 11 | kamenka
# Processing Record 15 of Set 11 | isla mujeres
# Processing Record 16 of Set 11 | davila
# Processing Record 17 of Set 11 | jonesboro
# Processing Record 18 of Set 11 | pompeu
# Processing Record 19 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 11 | koungou
# Processing Record 22 of Set 11 | oktyabrskoye
# Processing Record 23 of Set 11 | kerrobert
# Processing Record 24 of Set 11 | ikalamavony
# Processing Record 25 of Set 11 | sandwick
# Processing Record 26 of Set 11 | termiz
# Processing Record 27 of Set 11 | morondava
# Processing Record 28 of Set 11 | dafeng
# Processing Record 29 of Set 11 | aloleng
# Processing Record 30 of Set 11 | erenhot
# Processing Record 31 of Set 11 | hatta
# Processing Record 32 of Set 11 | naryan-mar
# Processing Record 33 of Set 11 | yanam
# Processing Record 34 of Set 11 | honningsvag
# Processing Record 35 of Set 11 | aksarka
# Processing Record 36 of Set 11 | vostok
# Processing Record 37 of Set 11 | wasilla
# Processing Record 38 of Set 11 | mana
# Processing Record 39 of Set 11 | yurga
# Processing Record 40 of Set 11 | calama
# Processing Record 41 of Set 11 | sheopur
# Processing Record 42 of Set 11 | ashford
# Processing Record 43 of Set 11 | acarau
# Processing Record 44 of Set 11 | ambilobe
# Processing Record 45 of Set 11 | aransas pass
# Processing Record 46 of Set 11 | coachella
# Processing Record 47 of Set 11 | hofn
# Processing Record 48 of Set 11 | shingu
# Processing Record 49 of Set 11 | alexandria
# Processing Record 50 of Set 11 | turukhansk
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | lima
# Processing Record 3 of Set 12 | alanya
# Processing Record 4 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 12 | noumea
# Processing Record 6 of Set 12 | aiken
# Processing Record 7 of Set 12 | kisangani
# Processing Record 8 of Set 12 | pasni
# Processing Record 9 of Set 12 | shelburne
# Processing Record 10 of Set 12 | saint-pierre
# Processing Record 11 of Set 12 | ust-maya
# Processing Record 12 of Set 12 | warwick
# Processing Record 13 of Set 12 | mandalgovi
# Processing Record 14 of Set 12 | bara
# Processing Record 15 of Set 12 | montepuez
# Processing Record 16 of Set 12 | rondonopolis
# Processing Record 17 of Set 12 | biak
# Processing Record 18 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 12 | kambove
# Processing Record 20 of Set 12 | novosergiyevka
# Processing Record 21 of Set 12 | sarvar
# Processing Record 22 of Set 12 | gwadar
# Processing Record 23 of Set 12 | ponnani
# Processing Record 24 of Set 12 | tondela
# Processing Record 25 of Set 12 | boddam
# Processing Record 26 of Set 12 | dingle
# Processing Record 27 of Set 12 | maubin
# Processing Record 28 of Set 12 | lagoa
# Processing Record 29 of Set 12 | chara
# Processing Record 30 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 12 | vinstra
# Processing Record 32 of Set 12 | nyrob
# Processing Record 33 of Set 12 | sogne
# Processing Record 34 of Set 12 | samarai
# Processing Record 35 of Set 12 | puerto ayacucho
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | ostrovnoy
# Processing Record 38 of Set 12 | pahrump
# Processing Record 39 of Set 12 | shubarkuduk
# Processing Record 40 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | ferrol
# Processing Record 43 of Set 12 | jalu
# Processing Record 44 of Set 12 | agadez
# Processing Record 45 of Set 12 | plettenberg bay
# Processing Record 46 of Set 12 | kampene
# Processing Record 47 of Set 12 | hebi
# Processing Record 48 of Set 12 | ende
# Processing Record 49 of Set 12 | kenai
# Processing Record 50 of Set 12 | barmer
# Processing Record 1 of Set 13 | nogliki
# Processing Record 2 of Set 13 | maragogi
# Processing Record 3 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | saint-augustin
# Processing Record 6 of Set 13 | kerema
# Processing Record 7 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 13 | yagodnoye
# Processing Record 10 of Set 13 | nizwa
# Processing Record 11 of Set 13 | pangody
# Processing Record 12 of Set 13 | cheney
# Processing Record 13 of Set 13 | shikhazany
# Processing Record 14 of Set 13 | karpathos
# Processing Record 15 of Set 13 | iskateley
# Processing Record 16 of Set 13 | savannah bight
# Processing Record 17 of Set 13 | griffith
# Processing Record 18 of Set 13 | constantine
# Processing Record 19 of Set 13 | salinas
# Processing Record 20 of Set 13 | nicoya
# Processing Record 21 of Set 13 | ulladulla
# Processing Record 22 of Set 13 | homer
# Processing Record 23 of Set 13 | berezovyy
# Processing Record 24 of Set 13 | umm kaddadah
# Processing Record 25 of Set 13 | les escoumins
# Processing Record 26 of Set 13 | puerto pinasco
# City not found. Skipping...
# Processing Record 27 of Set 13 | achisu
# Processing Record 28 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 13 | sunrise manor
# Processing Record 30 of Set 13 | lata
# Processing Record 31 of Set 13 | tura
# Processing Record 32 of Set 13 | kudahuvadhoo
# Processing Record 33 of Set 13 | kandrian
# Processing Record 34 of Set 13 | kharp
# Processing Record 35 of Set 13 | broken hill
# Processing Record 36 of Set 13 | ocu
# Processing Record 37 of Set 13 | maxixe
# Processing Record 38 of Set 13 | langfang
# Processing Record 39 of Set 13 | muroto
# Processing Record 40 of Set 13 | longyan
# Processing Record 41 of Set 13 | quatre cocos
# Processing Record 42 of Set 13 | labuan
# Processing Record 43 of Set 13 | port-gentil
# Processing Record 44 of Set 13 | aguimes
# Processing Record 45 of Set 13 | chingirlau
# Processing Record 46 of Set 13 | oranjemund
# Processing Record 47 of Set 13 | roald
# Processing Record 48 of Set 13 | hazorasp
# Processing Record 49 of Set 13 | maujao
# City not found. Skipping...
# Processing Record 50 of Set 13 | getulio vargas
# Processing Record 1 of Set 14 | manoel urbano
# Processing Record 2 of Set 14 | pedasi
# Processing Record 3 of Set 14 | taoudenni
# Processing Record 4 of Set 14 | coihaique
# Processing Record 5 of Set 14 | necocli
# Processing Record 6 of Set 14 | maceio
# Processing Record 7 of Set 14 | waipawa
# Processing Record 8 of Set 14 | deszk
# Processing Record 9 of Set 14 | korla
# Processing Record 10 of Set 14 | hadejia
# Processing Record 11 of Set 14 | ron phibun
# Processing Record 12 of Set 14 | kargasok
# Processing Record 13 of Set 14 | ligayan
# Processing Record 14 of Set 14 | manakara
# Processing Record 15 of Set 14 | moranbah
# Processing Record 16 of Set 14 | tshane
# Processing Record 17 of Set 14 | igarape-acu
# City not found. Skipping...
# Processing Record 18 of Set 14 | walvis bay
# Processing Record 19 of Set 14 | barreiras
# Processing Record 20 of Set 14 | epiniana
# Processing Record 21 of Set 14 | tiassale
# Processing Record 22 of Set 14 | udachnyy
# Processing Record 23 of Set 14 | watsa
# Processing Record 24 of Set 14 | gaeta
# Processing Record 25 of Set 14 | telimele
# Processing Record 26 of Set 14 | benxi
# Processing Record 27 of Set 14 | yefremov
# Processing Record 28 of Set 14 | ndele
# Processing Record 29 of Set 14 | sola
# Processing Record 30 of Set 14 | severnyy
# Processing Record 31 of Set 14 | impfondo
# Processing Record 32 of Set 14 | christchurch
# Processing Record 33 of Set 14 | anshun
# Processing Record 34 of Set 14 | saskatoon
# Processing Record 35 of Set 14 | hohhot
# Processing Record 36 of Set 14 | poplar bluff
# Processing Record 37 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 14 | la palma
# Processing Record 39 of Set 14 | bogorodskoye
# Processing Record 40 of Set 14 | lehututu
# Processing Record 41 of Set 14 | sistranda
# Processing Record 42 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 14 | ambo
# Processing Record 44 of Set 14 | moctezuma
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | saint-joseph
# Processing Record 47 of Set 14 | sangar
# Processing Record 48 of Set 14 | severodvinsk
# Processing Record 49 of Set 14 | nara
# Processing Record 50 of Set 14 | haines junction
# Processing Record 1 of Set 15 | akdepe
# Processing Record 2 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 15 | sovetskiy
# Processing Record 4 of Set 15 | sungairaya
# Processing Record 5 of Set 15 | ankara
# Processing Record 6 of Set 15 | vila velha
# Processing Record 7 of Set 15 | taganak
# Processing Record 8 of Set 15 | canmore
# Processing Record 9 of Set 15 | maldonado
# Processing Record 10 of Set 15 | atikokan
# Processing Record 11 of Set 15 | avera
# Processing Record 12 of Set 15 | ampanihy
# Processing Record 13 of Set 15 | tezu
# Processing Record 14 of Set 15 | maisuru
# City not found. Skipping...
# Processing Record 15 of Set 15 | lumphat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bredasdorp      ZA -34.5322   20.0403     62.60        77         100
# 1  Belaya Gora      RU  68.5333  146.4167    -12.62        90         100
# 2     Notodden      NO  59.5594    9.2585     28.99        53           8
# 3         Hilo      US  19.7297 -155.0900     73.99        78          90
# 4      Mataura      NZ -46.1927  168.8643     55.00        63          92
# 5    Upernavik      GL  72.7868  -56.1549    -18.96        82           0
# 6     Tasiilaq      GL  65.6145  -37.6368     33.80        86          90
# 7    Busselton      AU -33.6500  115.3333     64.00        87         100
# 8        Noyon      FR  49.5833    3.0000     37.00        86           0
# 9       Beyneu      KZ  45.3167   55.2000     28.76        89           0
#
#    Wind Speed Current Description
# 0        3.44     overcast clouds
# 1        7.85     overcast clouds
# 2        4.85           clear sky
# 3       11.50          light rain
# 4       13.00     overcast clouds
# 5       12.62           clear sky
# 6       36.82                snow
# 7        1.01     overcast clouds
# 8        8.05           clear sky
# 9       10.67           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
