# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | cap malheureux
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | sharjah
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 1 | grong
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | inirida
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | samarai
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | rudnogorsk
# Processing Record 23 of Set 1 | berlevag
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | lagos
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | seoul
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | farmington
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | dhali
# Processing Record 36 of Set 1 | hami
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | urengoy
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | huanren
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | raseiniai
# Processing Record 48 of Set 1 | hobyo
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | vila nova de milfontes
# Processing Record 1 of Set 2 | scarborough
# Processing Record 2 of Set 2 | bendigo
# Processing Record 3 of Set 2 | shuangcheng
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | kuandian
# Processing Record 7 of Set 2 | port lincoln
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | koungheul
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | karaton
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | coahuayana
# Processing Record 15 of Set 2 | merrill
# Processing Record 16 of Set 2 | valleyview
# Processing Record 17 of Set 2 | port keats
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | oksfjord
# Processing Record 20 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 2 | teshie
# Processing Record 22 of Set 2 | sompeta
# Processing Record 23 of Set 2 | faya
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | gashua
# Processing Record 27 of Set 2 | koumac
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | goderich
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | porto walter
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | dandong
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | saint-pierre
# Processing Record 39 of Set 2 | muriae
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | suriapet
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | svetlyy
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | portland
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | san rafael
# Processing Record 49 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | las vegas
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | tezu
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | san-pedro
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | kankan
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | christchurch
# Processing Record 11 of Set 3 | micheweni
# Processing Record 12 of Set 3 | montrose
# Processing Record 13 of Set 3 | bonfim
# Processing Record 14 of Set 3 | takoradi
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | ardakan
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | sisimiut
# Processing Record 20 of Set 3 | dwarka
# Processing Record 21 of Set 3 | lamu
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | vostok
# Processing Record 25 of Set 3 | guider
# Processing Record 26 of Set 3 | baie-comeau
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | magadan
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 3 | magan
# Processing Record 32 of Set 3 | matara
# Processing Record 33 of Set 3 | lusambo
# Processing Record 34 of Set 3 | nome
# Processing Record 35 of Set 3 | ormara
# Processing Record 36 of Set 3 | mayor pablo lagerenza
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | toora-khem
# Processing Record 39 of Set 3 | rumphi
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | santo antonio do ica
# Processing Record 44 of Set 3 | craig
# Processing Record 45 of Set 3 | maldonado
# Processing Record 46 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 3 | urumqi
# Processing Record 48 of Set 3 | gat
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | abha
# Processing Record 1 of Set 4 | tuatapere
# Processing Record 2 of Set 4 | tolaga bay
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | rantauprapat
# Processing Record 5 of Set 4 | ciudad bolivar
# Processing Record 6 of Set 4 | bom jesus
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | los llanos de aridane
# Processing Record 9 of Set 4 | mabaruma
# Processing Record 10 of Set 4 | anloga
# Processing Record 11 of Set 4 | port augusta
# Processing Record 12 of Set 4 | tome-acu
# City not found. Skipping...
# Processing Record 13 of Set 4 | alugan
# Processing Record 14 of Set 4 | morro bay
# Processing Record 15 of Set 4 | baykit
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 4 | conceicao do araguaia
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | aromashevo
# Processing Record 21 of Set 4 | asfi
# Processing Record 22 of Set 4 | pitimbu
# Processing Record 23 of Set 4 | batan
# Processing Record 24 of Set 4 | mercedes
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | banda aceh
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | krasnovishersk
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | borda da mata
# Processing Record 33 of Set 4 | chapleau
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | malakal
# Processing Record 36 of Set 4 | vaini
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | senovo
# Processing Record 42 of Set 4 | karratha
# Processing Record 43 of Set 4 | nara
# Processing Record 44 of Set 4 | aswan
# Processing Record 45 of Set 4 | fare
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | oktyabrskoye
# Processing Record 48 of Set 4 | hilo
# Processing Record 49 of Set 4 | dalinghe
# City not found. Skipping...
# Processing Record 50 of Set 4 | oyama
# Processing Record 1 of Set 5 | alhama de murcia
# Processing Record 2 of Set 5 | van
# Processing Record 3 of Set 5 | waipawa
# Processing Record 4 of Set 5 | galle
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | krasnokamensk
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | goure
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | mathbaria
# Processing Record 12 of Set 5 | werota
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | sorgun
# Processing Record 15 of Set 5 | bredasdorp
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | grand gaube
# Processing Record 18 of Set 5 | savannah bight
# Processing Record 19 of Set 5 | dafeng
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | paamiut
# Processing Record 22 of Set 5 | axim
# Processing Record 23 of Set 5 | ancud
# Processing Record 24 of Set 5 | indramayu
# Processing Record 25 of Set 5 | yining
# Processing Record 26 of Set 5 | polson
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | oum hadjer
# Processing Record 29 of Set 5 | moose factory
# Processing Record 30 of Set 5 | te anau
# Processing Record 31 of Set 5 | hambantota
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | nouadhibou
# Processing Record 34 of Set 5 | ostersund
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | kargopol
# Processing Record 37 of Set 5 | nalchiti
# Processing Record 38 of Set 5 | alice springs
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | walvis bay
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | yeppoon
# Processing Record 43 of Set 5 | vernon
# Processing Record 44 of Set 5 | bambanglipuro
# Processing Record 45 of Set 5 | bulawayo
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 48 of Set 5 | flinders
# Processing Record 49 of Set 5 | dikson
# Processing Record 50 of Set 5 | preobrazheniye
# Processing Record 1 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 6 | shingu
# Processing Record 3 of Set 6 | pedasi
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | san francisco
# Processing Record 6 of Set 6 | brae
# Processing Record 7 of Set 6 | kysyl-syr
# Processing Record 8 of Set 6 | makaha
# Processing Record 9 of Set 6 | passo de camaragibe
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | sorland
# Processing Record 12 of Set 6 | oussouye
# Processing Record 13 of Set 6 | havelock
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | ivankiv
# Processing Record 17 of Set 6 | saint-georges
# Processing Record 18 of Set 6 | chulumani
# Processing Record 19 of Set 6 | port hawkesbury
# Processing Record 20 of Set 6 | isla vista
# Processing Record 21 of Set 6 | ararat
# Processing Record 22 of Set 6 | angoram
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | tifton
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 6 | ordubad
# Processing Record 28 of Set 6 | puerto carreno
# Processing Record 29 of Set 6 | lorengau
# Processing Record 30 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 6 | lewistown
# Processing Record 32 of Set 6 | riyadh
# Processing Record 33 of Set 6 | fort nelson
# Processing Record 34 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 35 of Set 6 | finale ligure
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | russell
# Processing Record 38 of Set 6 | tulun
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | waddan
# Processing Record 43 of Set 6 | komsomolskiy
# Processing Record 44 of Set 6 | tete
# Processing Record 45 of Set 6 | dauriya
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | vila franca do campo
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | salalah
# Processing Record 1 of Set 7 | ituporanga
# Processing Record 2 of Set 7 | moshkovo
# Processing Record 3 of Set 7 | coffs harbour
# Processing Record 4 of Set 7 | zvishavane
# Processing Record 5 of Set 7 | ulety
# Processing Record 6 of Set 7 | mogadishu
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | umm kaddadah
# Processing Record 9 of Set 7 | khislavichi
# Processing Record 10 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 7 | requena
# Processing Record 12 of Set 7 | sistranda
# Processing Record 13 of Set 7 | bordighera
# Processing Record 14 of Set 7 | durban
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | gazojak
# Processing Record 17 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 7 | pusad
# Processing Record 19 of Set 7 | druzhba
# Processing Record 20 of Set 7 | port-gentil
# Processing Record 21 of Set 7 | trindade
# Processing Record 22 of Set 7 | aqtobe
# Processing Record 23 of Set 7 | liniere
# City not found. Skipping...
# Processing Record 24 of Set 7 | atambua
# Processing Record 25 of Set 7 | ko samui
# Processing Record 26 of Set 7 | sinnamary
# Processing Record 27 of Set 7 | grindavik
# Processing Record 28 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 7 | olenegorsk
# Processing Record 32 of Set 7 | kieta
# Processing Record 33 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 7 | sumbe
# Processing Record 35 of Set 7 | cidreira
# Processing Record 36 of Set 7 | tibati
# Processing Record 37 of Set 7 | shenjiamen
# Processing Record 38 of Set 7 | buala
# Processing Record 39 of Set 7 | hastings
# Processing Record 40 of Set 7 | ipixuna
# Processing Record 41 of Set 7 | berani
# Processing Record 42 of Set 7 | northam
# Processing Record 43 of Set 7 | lazaro cardenas
# Processing Record 44 of Set 7 | tabou
# Processing Record 45 of Set 7 | ramsar
# Processing Record 46 of Set 7 | ketchikan
# Processing Record 47 of Set 7 | ust-omchug
# Processing Record 48 of Set 7 | timizart
# Processing Record 49 of Set 7 | ishigaki
# Processing Record 50 of Set 7 | saint-leu
# Processing Record 1 of Set 8 | ambilobe
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | nabire
# Processing Record 4 of Set 8 | bonthe
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 8 | clarksburg
# Processing Record 8 of Set 8 | hualmay
# Processing Record 9 of Set 8 | biloela
# Processing Record 10 of Set 8 | iquique
# Processing Record 11 of Set 8 | santiago
# Processing Record 12 of Set 8 | forio
# Processing Record 13 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 8 | san fernando
# Processing Record 15 of Set 8 | jodhpur
# Processing Record 16 of Set 8 | boyabat
# Processing Record 17 of Set 8 | marshall
# Processing Record 18 of Set 8 | okhotsk
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | gazli
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | narsaq
# Processing Record 23 of Set 8 | port pirie
# Processing Record 24 of Set 8 | mount gambier
# Processing Record 25 of Set 8 | comodoro rivadavia
# Processing Record 26 of Set 8 | bengkulu
# Processing Record 27 of Set 8 | coquimbo
# Processing Record 28 of Set 8 | bria
# Processing Record 29 of Set 8 | novyy urengoy
# Processing Record 30 of Set 8 | rio grande
# Processing Record 31 of Set 8 | severo-yeniseyskiy
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | westport
# Processing Record 34 of Set 8 | xuddur
# Processing Record 35 of Set 8 | zyryanskoye
# Processing Record 36 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 8 | lexington
# Processing Record 38 of Set 8 | den helder
# Processing Record 39 of Set 8 | lagoa
# Processing Record 40 of Set 8 | champerico
# Processing Record 41 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 8 | qiyang
# Processing Record 43 of Set 8 | kedrovyy
# Processing Record 44 of Set 8 | petropavlivka
# Processing Record 45 of Set 8 | san ignacio
# Processing Record 46 of Set 8 | eydhafushi
# Processing Record 47 of Set 8 | yerofey pavlovich
# Processing Record 48 of Set 8 | bubaque
# Processing Record 49 of Set 8 | kenitra
# Processing Record 50 of Set 8 | egvekinot
# Processing Record 1 of Set 9 | plouzane
# Processing Record 2 of Set 9 | verkhnevilyuysk
# Processing Record 3 of Set 9 | rincon
# Processing Record 4 of Set 9 | scottsbluff
# Processing Record 5 of Set 9 | praia da vitoria
# Processing Record 6 of Set 9 | columbus
# Processing Record 7 of Set 9 | raga
# Processing Record 8 of Set 9 | oistins
# Processing Record 9 of Set 9 | nileshwar
# Processing Record 10 of Set 9 | buchanan
# Processing Record 11 of Set 9 | totness
# Processing Record 12 of Set 9 | sjovegan
# Processing Record 13 of Set 9 | macau
# Processing Record 14 of Set 9 | meiktila
# Processing Record 15 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 9 | nokha
# Processing Record 18 of Set 9 | sitrah
# Processing Record 19 of Set 9 | ponta delgada
# Processing Record 20 of Set 9 | saint-philippe
# Processing Record 21 of Set 9 | bahia honda
# Processing Record 22 of Set 9 | haines junction
# Processing Record 23 of Set 9 | sokoni
# Processing Record 24 of Set 9 | leshukonskoye
# Processing Record 25 of Set 9 | onega
# Processing Record 26 of Set 9 | moen
# Processing Record 27 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | gurlan
# Processing Record 30 of Set 9 | heishan
# Processing Record 31 of Set 9 | marienburg
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | saint-augustin
# Processing Record 34 of Set 9 | tobermory
# Processing Record 35 of Set 9 | iztapa
# Processing Record 36 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 9 | progreso
# Processing Record 38 of Set 9 | havre-saint-pierre
# Processing Record 39 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 9 | bumba
# Processing Record 41 of Set 9 | sakakah
# Processing Record 42 of Set 9 | barra
# Processing Record 43 of Set 9 | saint-gaudens
# Processing Record 44 of Set 9 | yerbogachen
# Processing Record 45 of Set 9 | vicuna
# Processing Record 46 of Set 9 | kandi
# Processing Record 47 of Set 9 | pingzhuang
# Processing Record 48 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 9 | aklavik
# Processing Record 1 of Set 10 | natal
# Processing Record 2 of Set 10 | hofn
# Processing Record 3 of Set 10 | terrace
# Processing Record 4 of Set 10 | aripuana
# Processing Record 5 of Set 10 | la mira
# Processing Record 6 of Set 10 | bacolod
# Processing Record 7 of Set 10 | rafai
# Processing Record 8 of Set 10 | bushehr
# Processing Record 9 of Set 10 | silae
# Processing Record 10 of Set 10 | porto novo
# Processing Record 11 of Set 10 | magna
# Processing Record 12 of Set 10 | xam nua
# Processing Record 13 of Set 10 | moorhead
# Processing Record 14 of Set 10 | bathsheba
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | omboue
# Processing Record 17 of Set 10 | grande prairie
# Processing Record 18 of Set 10 | nenjiang
# Processing Record 19 of Set 10 | arona
# Processing Record 20 of Set 10 | flagstaff
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | acapulco
# Processing Record 23 of Set 10 | shangrao
# Processing Record 24 of Set 10 | maunabo
# Processing Record 25 of Set 10 | richards bay
# Processing Record 26 of Set 10 | kurchum
# Processing Record 27 of Set 10 | wenzhou
# Processing Record 28 of Set 10 | naantali
# Processing Record 29 of Set 10 | suluq
# Processing Record 30 of Set 10 | metro
# Processing Record 31 of Set 10 | kidal
# Processing Record 32 of Set 10 | santa maria
# Processing Record 33 of Set 10 | whitehorse
# Processing Record 34 of Set 10 | murgab
# Processing Record 35 of Set 10 | igarka
# Processing Record 36 of Set 10 | ulladulla
# Processing Record 37 of Set 10 | borama
# City not found. Skipping...
# Processing Record 38 of Set 10 | yinchuan
# Processing Record 39 of Set 10 | gitarama
# Processing Record 40 of Set 10 | begunitsy
# Processing Record 41 of Set 10 | rawson
# Processing Record 42 of Set 10 | cleburne
# Processing Record 43 of Set 10 | kuna
# Processing Record 44 of Set 10 | oranjemund
# Processing Record 45 of Set 10 | alofi
# Processing Record 46 of Set 10 | melnikovo
# Processing Record 47 of Set 10 | swift current
# Processing Record 48 of Set 10 | laguna
# Processing Record 49 of Set 10 | petrolandia
# City not found. Skipping...
# Processing Record 50 of Set 10 | olenino
# Processing Record 1 of Set 11 | merritt island
# Processing Record 2 of Set 11 | karagaylinskiy
# Processing Record 3 of Set 11 | sokoto
# Processing Record 4 of Set 11 | ha
# City not found. Skipping...
# Processing Record 5 of Set 11 | norfolk
# Processing Record 6 of Set 11 | maumere
# Processing Record 7 of Set 11 | matay
# Processing Record 8 of Set 11 | kalmanka
# Processing Record 9 of Set 11 | turukhansk
# Processing Record 10 of Set 11 | kapit
# Processing Record 11 of Set 11 | great yarmouth
# Processing Record 12 of Set 11 | megion
# Processing Record 13 of Set 11 | port blair
# Processing Record 14 of Set 11 | qui nhon
# Processing Record 15 of Set 11 | liwale
# Processing Record 16 of Set 11 | kochki
# Processing Record 17 of Set 11 | bwanga
# Processing Record 18 of Set 11 | itoman
# Processing Record 19 of Set 11 | avera
# Processing Record 20 of Set 11 | necochea
# Processing Record 21 of Set 11 | swinoujscie
# Processing Record 22 of Set 11 | mbandaka
# Processing Record 23 of Set 11 | the valley
# Processing Record 24 of Set 11 | southbridge
# Processing Record 25 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 11 | tubmanburg
# Processing Record 27 of Set 11 | teahupoo
# Processing Record 28 of Set 11 | twin falls
# Processing Record 29 of Set 11 | maputo
# Processing Record 30 of Set 11 | coxim
# Processing Record 31 of Set 11 | lakes entrance
# Processing Record 32 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 33 of Set 11 | la rioja
# Processing Record 34 of Set 11 | tay ninh
# Processing Record 35 of Set 11 | krasnorechenskiy
# Processing Record 36 of Set 11 | key west
# Processing Record 37 of Set 11 | pafos
# Processing Record 38 of Set 11 | dasoguz
# Processing Record 39 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 11 | busko-zdroj
# Processing Record 41 of Set 11 | tubuala
# Processing Record 42 of Set 11 | sadiqabad
# Processing Record 43 of Set 11 | fayetteville
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | nicoya
# Processing Record 46 of Set 11 | dourbali
# Processing Record 47 of Set 11 | bitung
# Processing Record 48 of Set 11 | abeokuta
# Processing Record 49 of Set 11 | polewali
# Processing Record 50 of Set 11 | maniwaki
# Processing Record 1 of Set 12 | sawtell
# Processing Record 2 of Set 12 | chicama
# Processing Record 3 of Set 12 | ferrol
# Processing Record 4 of Set 12 | puri
# Processing Record 5 of Set 12 | touros
# Processing Record 6 of Set 12 | prince rupert
# Processing Record 7 of Set 12 | whyalla
# Processing Record 8 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 12 | mareeba
# Processing Record 10 of Set 12 | limbazi
# Processing Record 11 of Set 12 | montague
# Processing Record 12 of Set 12 | saint-francois
# Processing Record 13 of Set 12 | kadoma
# Processing Record 14 of Set 12 | uyuni
# Processing Record 15 of Set 12 | abu zabad
# Processing Record 16 of Set 12 | svetlogorsk
# Processing Record 17 of Set 12 | erenhot
# Processing Record 18 of Set 12 | khani
# Processing Record 19 of Set 12 | emerald
# Processing Record 20 of Set 12 | srednekolymsk
# Processing Record 21 of Set 12 | kaihua
# Processing Record 22 of Set 12 | thohoyandou
# Processing Record 23 of Set 12 | prieska
# Processing Record 24 of Set 12 | mae hong son
# Processing Record 25 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 26 of Set 12 | inhambane
# Processing Record 27 of Set 12 | golden
# Processing Record 28 of Set 12 | atar
# Processing Record 29 of Set 12 | warmbad
# Processing Record 30 of Set 12 | dakoro
# Processing Record 31 of Set 12 | honiara
# Processing Record 32 of Set 12 | adeje
# Processing Record 33 of Set 12 | celestun
# Processing Record 34 of Set 12 | cabedelo
# Processing Record 35 of Set 12 | yulara
# Processing Record 36 of Set 12 | zhanaozen
# Processing Record 37 of Set 12 | khash
# Processing Record 38 of Set 12 | edson
# Processing Record 39 of Set 12 | rawlins
# Processing Record 40 of Set 12 | koslan
# Processing Record 41 of Set 12 | shelburne
# Processing Record 42 of Set 12 | kaya
# Processing Record 43 of Set 12 | kaliua
# Processing Record 44 of Set 12 | reguengos de monsaraz
# Processing Record 45 of Set 12 | olafsvik
# Processing Record 46 of Set 12 | jalu
# Processing Record 47 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 12 | bodden town
# Processing Record 49 of Set 12 | suez
# Processing Record 50 of Set 12 | neuquen
# Processing Record 1 of Set 13 | nautla
# Processing Record 2 of Set 13 | baruun-urt
# Processing Record 3 of Set 13 | grand forks
# Processing Record 4 of Set 13 | rybachiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 604

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187   19.2345     59.00        91          79
# 1  Cap Malheureux -19.9842   57.6142     75.00        81          78
# 2       Busselton -33.6500  115.3333     66.99        99          87
# 3         Sharjah  25.3573   55.4033     78.80        56           0
# 4       Hithadhoo  -0.6000   73.0833     82.83        70          72
# 5     Tuktoyaktuk  69.4541 -133.0374    -20.20        76          20
# 6     Yellowknife  62.4560 -114.3525     -5.01        71          90
# 7         Fortuna  40.5982 -124.1573     61.00        51          51
# 8           Grong  64.4654   12.3149     30.20        93          75
# 9          Castro -24.7911  -50.0119     64.36        96         100
#
#    Wind Speed Country                 Date
# 0        6.51      ZA  2021-03-04 20:42:55
# 1        4.00      MU  2021-03-04 20:42:55
# 2        6.78      AU  2021-03-04 20:42:55
# 3        2.30      AE  2021-03-04 20:42:55
# 4        8.77      MV  2021-03-04 20:42:56
# 5        8.05      CA  2021-03-04 20:42:56
# 6       13.80      CA  2021-03-04 20:42:56
# 7        8.99      US  2021-03-04 20:42:56
# 8        5.75      NO  2021-03-04 20:42:57
# 9        7.94      BR  2021-03-04 20:42:57

# %%
# Reorder the columns 
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0        Hermanus      ZA  2021-03-04 20:42:55 -34.4187   19.2345     59.00
# 1  Cap Malheureux      MU  2021-03-04 20:42:55 -19.9842   57.6142     75.00
# 2       Busselton      AU  2021-03-04 20:42:55 -33.6500  115.3333     66.99
# 3         Sharjah      AE  2021-03-04 20:42:55  25.3573   55.4033     78.80
# 4       Hithadhoo      MV  2021-03-04 20:42:56  -0.6000   73.0833     82.83
# 5     Tuktoyaktuk      CA  2021-03-04 20:42:56  69.4541 -133.0374    -20.20
# 6     Yellowknife      CA  2021-03-04 20:42:56  62.4560 -114.3525     -5.01
# 7         Fortuna      US  2021-03-04 20:42:56  40.5982 -124.1573     61.00
# 8           Grong      NO  2021-03-04 20:42:57  64.4654   12.3149     30.20
# 9          Castro      BR  2021-03-04 20:42:57 -24.7911  -50.0119     64.36
#
#    Humidity  Cloudiness  Wind Speed
# 0        91          79        6.51
# 1        81          78        4.00
# 2        99          87        6.78
# 3        56           0        2.30
# 4        70          72        8.77
# 5        76          20        8.05
# 6        71          90       13.80
# 7        51          51        8.99
# 8        93          75        5.75
# 9        96         100        7.94

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#create new dataframe using loc 
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Cape Town
# Country                        ZA
# Date          2021-03-04 20:38:54
# Lat                      -33.9258
# Lng                       18.4232
# Max Temp                    66.99
# Humidity                       63
# Cloudiness                      0
# Wind Speed                  12.66
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 3      Sharjah      AE  2021-03-04 20:42:55  25.3573   55.4033     78.80
# 5  Tuktoyaktuk      CA  2021-03-04 20:42:56  69.4541 -133.0374    -20.20
# 6  Yellowknife      CA  2021-03-04 20:42:56  62.4560 -114.3525     -5.01
# 7      Fortuna      US  2021-03-04 20:42:56  40.5982 -124.1573     61.00
# 8        Grong      NO  2021-03-04 20:42:57  64.4654   12.3149     30.20
#
#    Humidity  Cloudiness  Wind Speed
# 3        56           0        2.30
# 5        76          20        8.05
# 6        71          90       13.80
# 7        51          51        8.99
# 8        93          75        5.75

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere (Max temp)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plt.title('Linear Regression on the Northern Hemisphere\nfor Maximum Temperature')
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(0,-20))

# %%
# Linear regression on the Southern Hemisphere (Max temp)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plt.title('Linear Regression on the Southern Hemisphere\nfor Maximum Temperature')
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,88))

# %%
# Linear regression on the Northern Hemisphere (% Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plt.title("Linear Regression on the Northern Hemisphere\nfor % Humidity")
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere (% Humidity)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plt.title("Linear Regression on the Southern Hemisphere\nfor % Humidity")
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor % Humidity', '% Humidity',(-25,40))

# %%
# Linear regression on the Northern Hemisphere (%Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.title("Linear Regression on the Northern Hemisphere\nfor % Cloudiness")
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere (% Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plt.title("Linear Regression on the Southern Hemisphere\nfor % Cloudiness")
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-55,60))

# %%
# Linear regression on the Northern Hemisphere (Wind speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plt.title("Linear Regression on the Northern Hemisphere\nfor Wind Speed")
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor Wind Speed', 'Wind Speed (mph)',(10,30))

# %%
# Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plt.title('Linear Regression on the Southern Hemisphere\nfor Wind Speed')
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor Wind Speed', 
                       'Wind Speed (mph)',(-55,10))
